# %%
import pandas as pd
import glob
import os

# %%
# setting the path for joining multiple files
files = os.path.join("C:/Users/gtoos/OneDrive/Desktop/area1", "1_*.csv")

# %%
# list of merged files returned
files = glob.glob(files)

# %%
print("Resultant CSV after joining all CSV files at a particular location...");
# Out:
# Resultant CSV after joining all CSV files at a particular location...

# %%
# joining files with concat and read_csv
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
print(df)
Area_1 = df.to_csv('Area_1_appended.csv', index=False)
# Out:
#          Date  Drought Level Index  Precipitation_in  Temperature_C  \
# 0     2000-02             1.754260              0.32      25.557100
# 1     2000-03             2.016075              3.07      26.973700
# 2     2000-04             0.296925              2.36      33.351775
# 3     2000-05             0.406600              1.02      40.815733
# 4     2000-06             0.250000              4.55      36.667025
# ...       ...                  ...               ...            ...
# 2488  2022-10             2.803975              3.03      32.893050
# 2489  2022-11             2.508920              0.87      18.654900
# 2490  2022-12             2.509700              0.28      20.806250
# 2491  2023-01             2.509700              0.33      22.382025
# 2492      NaN                  NaN               NaN      22.144600
#
#       Vegetation  Evapotranspiration
# 0        0.20440            1.640400
# 1        0.21600            2.716475
# 2        0.27375            1.790225
# 3        0.29960            1.057933
# 4        0.40450            3.800975
# ...          ...                 ...
# 2488     0.32830                 NaN
# 2489     0.31545                 NaN
# 2490     0.26840                 NaN
# 2491     0.26785                 NaN
# 2492     0.27130                 NaN
#
# [2493 rows x 6 columns]

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#Dropping the null rows
#before dropping
print(df.shape)
#after dropping
df1 = df.dropna()
print(df1.shape)
# Out:
# (2493, 6)
# (2367, 6)

# %%
Area_1 = df1.to_csv('CleanArea_1_appended.csv', index=False)
